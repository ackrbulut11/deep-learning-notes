# %%
# !pip install torch torchvision

# %%
import numpy as np
import torch

# %%
scalar = torch.tensor(12)
scalar
# Out:
# tensor(12)

# %%
type(scalar) # skaler, vektör, matrix, tensör -- hepsinin type tensor olur.
# Out:
# torch.Tensor

# %%
scalar + 3
# Out:
# tensor(15)

# %%
scalar//2
# Out:
# tensor(6)

# %%
scalar * 33
# Out:
# tensor(396)

# %%
scalar.dim() # 0 dimension çünkü skalar
# Out:
# 0

# %%
scalar.shape
# Out:
# torch.Size([])

# %%
scalar.dtype
# Out:
# torch.int64

# %%
vektor = torch.tensor(33, dtype = torch.int32) # default dtype torch.int64

# %%
vektor
# Out:
# tensor(33, dtype=torch.int32)

# %%
tensor_float = torch.tensor(3.14)
tensor_float
# Out:
# tensor(3.1400)

# %%
tensor_float.dtype
# Out:
# torch.float32

# %% [markdown]
# ### Vectors

# %%
vector = torch.tensor([2, 3])
vector
# Out:
# tensor([2, 3])

# %%
vector.ndim # 1 dimensional
# Out:
# 1

# %%
vector.shape
# Out:
# torch.Size([2])

# %% [markdown]
# Boyut sayısını belirlemek için köşeli parantez sayısına bakılır.
# Shape belirlemek için her boyuttaki eleman sayısına bakılır.

# %%
vector2 = torch.tensor([2,3,4,5,12])
vector2.shape
# Out:
# torch.Size([5])

# %%
vector2.dim()
# Out:
# 1

# %% [markdown]
# ### Markdown

# %%
matrix = torch.tensor([[2, 3], [3, 5]])
matrix
# Out:
# tensor([[2, 3],
#         [3, 5]])

# %%
matrix.dtype
# Out:
# torch.int64

# %%
matrix.shape
# Out:
# torch.Size([2, 2])

# %%
matrix.dim()
# Out:
# 2

# %% [markdown]
# ### Tensor

# %%
tensor = torch.tensor([[[1,2,3],[1,2,3],[3,4,1]],[[1,2,3],[2,9,7],[2,2,5]]])

# %%
tensor
# Out:
# tensor([[[1, 2, 3],
#          [1, 2, 3],
#          [3, 4, 1]],
#
#         [[1, 2, 3],
#          [2, 9, 7],
#          [2, 2, 5]]])

# %%
tensor.dim()
# Out:
# 3

# %%
tensor.shape
# Out:
# torch.Size([2, 3, 3])

# %%
tensor2 = torch.tensor([[[1,2,3],[1,2,3],[3,4,1]],[[1,2,3],[2,9,7],[2,2,5]],[[1,2,3],[1,2,3],[3,4,1]]])

# %%
tensor2.shape
# Out:
# torch.Size([3, 3, 3])

# %%
tensor3 = torch.tensor([[[1,3],[1,2],[4,1]]])

# %%
tensor3.shape
# Out:
# torch.Size([1, 3, 2])

# %%
float_16_tensor = torch.tensor(
    [3.2, 5.0, 3.0],
    dtype = torch.float16, # default or custom?
    device = None, # cpu or gpu?
    requires_grad = False  # öğrenme olacak mı?
)

# %%
float_16_tensor.dim()
# Out:
# 1

# %%
float_16_tensor.dtype
# Out:
# torch.float16
